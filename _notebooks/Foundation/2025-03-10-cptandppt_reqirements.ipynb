# %% [raw]
# ---
# layout: post
# title: CPT and PPR
# description: This is a Jupyter Notebook where I blog my PPR and CPT.
# permalink: /cptandppr/
# ---

# %% [markdown]
# # 🎉 **Program Breakdown & Explanation** 🎉
#
# ---
#
# ## **✨ Component A: Program Code** ✨
#
# ### ![Program Code Screenshot 1](https://github.com/user-attachments/assets/a7b0e2a7-607a-4650-b444-48ba7d5d71b7)
# *The heart of the program: our code!*
#
# ### ![Program Code Screenshot 2](https://github.com/user-attachments/assets/b2015326-9c5c-49cd-a818-670383bd78be)
# *In action: showcasing the beautiful logic.*
#
# ---
#
# ## **📝 1. User Input** 📝
#
# In this part, we gather valuable input from the user to drive the program’s functionality.
#
# ### ![User Input Screenshot](https://github.com/user-attachments/assets/478ac847-2fc7-47a5-9c19-dfc4759c9ac2)
# _The interface that asks the user for input._
#
# ---
#
# ## **📊 2. Data Representation Using Lists** 📊
#
# Lists are the backbone of data storage in our program, organizing the input in an easy-to-manage structure.
#
# ### ![Lists Representation Screenshot](https://github.com/user-attachments/assets/28cc41bb-5b7e-41f2-9ca5-3a53c02153aa)
# _A glimpse into how we manage our data._
#
# ---
#
# ## **⚙️ Component B: Functionality & Algorithm** ⚙️
#
# ### **🔧 3. Student-Developed Procedure** 🔧
#
# Here’s the custom procedure I built to handle the functionality of the program.
#
# #### ![Student Procedure Screenshot](https://github.com/user-attachments/assets/9a82ca96-fc95-4fe3-a5be-f401438aa19f)
#
# ---
#
# ## **💡 4. Algorithm with Sequencing, Selection, and Iteration** 💡
#
# Let’s break it down into its core components:
#
# ### **🎬 Sequencing:**
#
# Each line of code follows a strict order to ensure the program works smoothly. Here's how it's done:
#
# ![Sequencing Screenshot](https://github.com/user-attachments/assets/41fecdb6-1a4f-4673-894e-aae3e896f092)
#
# ---
#
# ### **⚖️ Selection:**
#
# With decision-making logic, the program can make choices based on input, ensuring accurate error handling.
#
# ![Selection Screenshot](https://github.com/user-attachments/assets/064a5c01-e6fd-455a-9fb9-d81922998981)
#
# ---
#
# ### **🔄 Iteration:**
#
# We loop through the data, ensuring that everything gets processed and handled appropriately.
#
# ![Iteration Screenshot](https://github.com/user-attachments/assets/ceac315a-7567-47ef-84e1-1b7c69415216)
#
# ---
#
# ## **🔑 5. Procedure Calls** 🔑
#
# Here we invoke the procedure, bringing all the magic together and executing the core functionality!
#
# ![Procedure Call Screenshot](https://github.com/user-attachments/assets/6d08bfb5-2c2c-4e81-a98c-659a1e182c2d)
#
# ---
#
# ## **📤 6. Output Based on Input** 📤
#
# Once the user inputs their data, the program produces output tailored to their entries.
#
# ### ![Output Screenshot](https://github.com/user-attachments/assets/bc58996a-c104-48bb-8d4c-40b84f8cf9f7)
# _This is the outcome when everything works perfectly._
#
# ---
#
# ## **🎥 Component C: Video Demonstration** 🎥
#
# ### **Showcasing the Program in Action!**
#
# In this video, you will see:
# - Input being entered into the program.
# - Key functionality that drives the code.
# - The output the program generates.
#
# ### **Video Requirements:**
# - **Format:** .webm, .mp4, .wmv, .avi, or .mov
# - **Length:** 1 minute max
# - **Size:** 30MB max
#
# ---
#
# ### Watch the full demo here! 🌟
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/KKf0MTIp5xg" frameborder="0" allowfullscreen></iframe>
